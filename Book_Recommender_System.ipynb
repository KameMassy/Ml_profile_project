# %% [markdown]
# <a href="https://colab.research.google.com/github/KameMassy/Ml_profile_project/blob/main/Book_Recommender_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('Books.csv')
ratings = pd.read_csv('Ratings.csv')

# %%
users = pd.read_csv('Users.csv')

# %%
books.head(3)
# Out:
#          ISBN            Book-Title           Book-Author  \
# 0  0195153448   Classical Mythology    Mark P. O. Morford
# 1  0002005018          Clara Callan  Richard Bruce Wright
# 2  0060973129  Decision in Normandy          Carlo D'Este
#
#    Year-Of-Publication                Publisher  \
# 0               2002.0  Oxford University Press
# 1               2001.0    HarperFlamingo Canada
# 2               1991.0          HarperPerennial
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-L
# ...

# %%
ratings.head(3)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X          0.0
# 1   276726  0155061224          5.0
# 2   276727  0446520802          0.0

# %%
users.head(3)
# Out:
#    User-ID                         Location   Age
# 0        1               nyc, new york, usa   NaN
# 1        2        stockton, california, usa  18.0
# 2        3  moscow, yukon territory, russia   NaN

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (15868, 8)
# (221153, 3)
# (107876, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    1
# Publisher              1
# Image-URL-S            1
# Image-URL-M            1
# Image-URL-L            1
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           1
# Book-Rating    1
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID         0
# Location        1
# Age         42838
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #Popularity Based Recommender System

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                            Book-Title  num_ratings
# 0                                        It Takes Two            2
# 1                        Tales of Terror and Suspense            1
# 2                                                 '48            1
# 3                                        'Salem's Lot            3
# 4             .Hack: //Legend of the Twilight, Vol. 1            4
# ...                                               ...          ...
# 14965  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)            1
# 14966                                        stardust            9
# 14967                Â¿QuiÃ©n se ha llevado mi queso?            1
# 14968                        Â¿QuÃ© me quieres, amor?            2
# 14969                           Ã?Â?ber die Freiheit.            1
#
# [14970 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
# <ipython-input-17-ebeed7a91fd4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
#                                            Book-Title  avg_rating
# 0                                        It Takes Two    0.000000
# 1                        Tales of Terror and Suspense    0.000000
# 2                                                 '48    0.000000
# 3                                        'Salem's Lot    3.333333
# 4             .Hack: //Legend of the Twilight, Vol. 1    6.500000
# ...                                               ...         ...
# 14965  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)    8.000000
# 14966                                        stardust    1.777778
# ...

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                            Book-Title  num_ratings  avg_rating
# 0                                        It Takes Two            2    0.000000
# 1                        Tales of Terror and Suspense            1    0.000000
# 2                                                 '48            1    0.000000
# 3                                        'Salem's Lot            3    3.333333
# 4             .Hack: //Legend of the Twilight, Vol. 1            4    6.500000
# ...                                               ...          ...         ...
# 14965  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)            1    8.000000
# 14966                                        stardust            9    1.777778
# 14967                Â¿QuiÃ©n se ha llevado mi queso?            1    7.000000
# 14968                        Â¿QuÃ© me quieres, amor?            2    3.000000
# 14969                           Ã?Â?ber die Freiheit.            1    7.000000
#
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings', 'avg_rating']]

# %%
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0316666343.01.MZZZZZZZ.jpg'

# %% [markdown]
# #Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
golden_users = x[x].index

# %%
new_rating = ratings_with_name[ratings_with_name['User-ID'].isin(golden_users)]

# %%
y = new_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = new_rating[new_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-707e6a29efa1> in <cell line: 1>()
# ----> 1 similarity_scores = cosine_similarity(pt)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1391     # to avoid recursive import
#    1392
# -> 1393     X, Y = check_pairwise_arrays(X, Y)
#    1394
#    1395     X_normalized = normalize(X, copy=True)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     144
#     145     if Y is X or Y is None:
# --> 146         X = Y = check_array(
#     147             X,
#     148             accept_sparse=accept_sparse,
#
# ...

# %%
similarity_scores.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-0b69d7892d18> in <cell line: 1>()
# ----> 1 similarity_scores.shape
#
# NameError: name 'similarity_scores' is not defined

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]

    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)

    return data

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#              ISBN                                         Book-Title  \
# 0      0195153448                                Classical Mythology
# 1      0002005018                                       Clara Callan
# 2      0060973129                               Decision in Normandy
# 3      0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4      0393045218                             The Mummies of Urumchi
# ...           ...                                                ...
# 15863  0316353299             Blue Highways : A Journey into America
# 15864  1869503171                                     Spirit Writing
# 15865  0767903862                             In a Sunburned Country
# 15866  0060931671                               The Crying of Lot 49
# 15867  0060730552                                    Touching the Vo
#
#                    Book-Author  Year-Of-Publication  \
# 0           Mark P. O. Morford               2002.0
# ...

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
# pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
new_ratings=final_ratings
def change_url(param):
    if isinstance(param,str):
        param=param.replace('http','https')
    return param

new_ratings['new_Image-URL-L']=new_ratings['Image-URL-L'].apply(change_url)
